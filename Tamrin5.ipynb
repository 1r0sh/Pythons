# %%
def num(x):
    if(x==10):
        return x
    elif(x<10):
        return num(x+1)

num(1)
# Out:
# 10

# %%
#Addition
print(2+1)
print(3+34)
print(35+2)
print(65+34)
print(6+52)
print(1+1)
print(3+34)
print(4+4)
print(5+34)
print(10+89)

#Subtraction
print(1-1)
print(2-3)
print(5-2)
print(345-3)
print(134-45)
print(434-984)
print(45-59)
print(18-4)
print(41-3)

#Multipliction
print(1*2)
print(6*4)
print(11*7)
print(3*1)
print(33*2)
print(8*34)
print(2*5)
print(4*5)
print(44*4)
print(2*3)

#division

print(2/1)
print(23/2)
print(21/2)
print(34//2)
print(454//3)
print(45/2)
print(1//1)
print(234%5)
print(45%4)

#Comparison
y = 1
x = 3

print(a > b)
print(4 > 2)
print(a < b)
print(5 < 1)
print(a == b)
print(4 == 1)
print(a != b)
print(6 != 1)
print(a >= b)
print(5 >= 1)
print(a <= b)

#Logical
#and
print(1 and 0)
print(0 and 1)
print(2 and 2)
print(45 and 3)
print(6 and 4)
print(2 and 5)
print(0 and 6)
print(0 and 7)
print(0 and 8)
#or
print(1 or 0)
print(1 or 1)
print(1 or 2)
print(0 or 0)
print(23 or 0)
print(12 or 1)
print(1 or 2)
print(10 or 3)
print(13 or 0)
print(67 or 0)
print(5 or 1)
#not
print(not 6)
print(not 9)
print(not 0)
print(not 5)
print(not 4)
print(not 3)
print(not 2)
print(not 1)
print(not 0)
# Out:
# 3

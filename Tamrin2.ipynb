# %%
def get_y1():
    y=5
    return y
    
def get_y2(x):
    y=x
    return y 
    
def get_y3(a,b,c,x):
    y=(a*x**2)+(b*x)+c
    return y
    
def get_y4(a,b,c,d,x):
    y=(a*x**3)+(b*x**2)+(c*x)+d
    return y
    
def get_y5(a,x):
    y=a**x
    return y
    
def get_y6(x):
    y=-x
    return y
    
def get_y7(a,d,f,w):
    y=w-(a*(d/f))
    return y
    
def get_y8(a,b,x,z):
    y=(a*x)+(b*z)
    return y

# %%
get_y1()
# Out:
# 5

# %%
get_y2(464)
# Out:
# 464

# %%
get_y3(1,2,3,4)
# Out:
# 27

# %%
get_y4(1,2,3,4,5)
# Out:
# 194

# %%
get_y5(3,5)
# Out:
# 243

# %%
get_y6(2)
# Out:
# -2

# %%
get_y7(3,5,7,1)
# Out:
# -1.1428571428571428

# %%
get_y8(3,4,1,6)
# Out:
# 27
